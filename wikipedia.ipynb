# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./dataset/sampledata.csv', on_bad_lines='skip', header=None, sep='\t')
df.head()
# Out:
#            0              1  \
# 0  929840853  1190146243326
# 1  929840856  1190146243321
# 2  929840854  1190146243311
# 3  929840855  1190146243301
# 4  929840857  1190146243303
#
#                                                    2  3    4
# 0  http://upload.wikimedia.org/wikipedia/en/thumb...  -  NaN
# 1         http://en.wikipedia.org/images/wiki-en.png  -  NaN
# 2  http://upload.wikimedia.org/wikipedia/commons/...  -  NaN
# 3  http://es.wikipedia.org/w/index.php?title=-&ac...  -  NaN
# 4  http://en.wikipedia.org/w/index.php?title=Medi...  -  NaN

# %%
df.drop(columns=4, inplace=True)

# %%
df.head()
# Out:
#            0              1  \
# 0  929840853  1190146243326
# 1  929840856  1190146243321
# 2  929840854  1190146243311
# 3  929840855  1190146243301
# 4  929840857  1190146243303
#
#                                                    2  3
# 0  http://upload.wikimedia.org/wikipedia/en/thumb...  -
# 1         http://en.wikipedia.org/images/wiki-en.png  -
# 2  http://upload.wikimedia.org/wikipedia/commons/...  -
# 3  http://es.wikipedia.org/w/index.php?title=-&ac...  -
# 4  http://en.wikipedia.org/w/index.php?title=Medi...  -

# %%
df.columns = ['monotonic', 'timestamp', 'url', 'flag']

# %%
df.head()
# Out:
#    monotonic      timestamp  \
# 0  929840853  1190146243326
# 1  929840856  1190146243321
# 2  929840854  1190146243311
# 3  929840855  1190146243301
# 4  929840857  1190146243303
#
#                                                  url flag
# 0  http://upload.wikimedia.org/wikipedia/en/thumb...    -
# 1         http://en.wikipedia.org/images/wiki-en.png    -
# 2  http://upload.wikimedia.org/wikipedia/commons/...    -
# 3  http://es.wikipedia.org/w/index.php?title=-&ac...    -
# 4  http://en.wikipedia.org/w/index.php?title=Medi...    -

# %%
df.shape
# Out:
# (1036, 4)

# %%
df.url.nunique()
# Out:
# 755

# %%
df.flag.unique()
# Out:
# array(['-', '%20wolna%20encyklopedia_pliki/index.css'], dtype=object)

# %%
df.sort_values(by=['monotonic'])
# Out:
#       monotonic      timestamp  \
# 0     929840853  1190146243326
# 2     929840854  1190146243311
# 3     929840855  1190146243301
# 1     929840856  1190146243321
# 4     929840857  1190146243303
# ...         ...            ...
# 1032  929841884  1190146243652
# 1031  929841885   119014624366
# 1033  929841887  1190146243628
# 1034  929841890  1190146243655
# 1035  929841892  1190146243656
#
#                                                     url flag
# 0     http://upload.wikimedia.org/wikipedia/en/thumb...    -
# 2     http://upload.wikimedia.org/wikipedia/commons/...    -
# 3     http://es.wikipedia.org/w/index.php?title=-&ac...    -
# 1            http://en.wikipedia.org/images/wiki-en.png    -
# 4     http://en.wikipedia.org/w/index.php?title=Medi...    -
# ...                                                 ...  ...
# 1032  http://upload.wikimedia.org/wikipedia/commons/...    -
# 1031  http://en.wikipedia.org/wiki/Florence_Nightingale    -
# 1033  http://commons.wikimedia.org/w/index.php?title...    -
# 1034  http://en.wikipedia.org/wiki/List_of_The_4400_...    -
# 1035  http://meta.wikimedia.org/w/index.php?title=Me...    -
#
# [1036 rows x 4 columns]

# %%
upload = df[df.url.str.contains('upload')]

# %%
upload.head()
# Out:
#    monotonic      timestamp  \
# 0  929840853  1190146243326
# 2  929840854  1190146243311
# 5  929840858  1190146243314
# 7  929840859  1190146243296
# 9  929840861  1190146243292
#
#                                                  url flag
# 0  http://upload.wikimedia.org/wikipedia/en/thumb...    -
# 2  http://upload.wikimedia.org/wikipedia/commons/...    -
# 5  http://upload.wikimedia.org/wikipedia/en/thumb...    -
# 7  http://upload.wikimedia.org/wikipedia/commons/...    -
# 9  http://upload.wikimedia.org/wikipedia/commons/...    -

# %%
upload.shape
# Out:
# (516, 4)

# %%
upload.url.nunique()
# Out:
# 447

# %%
upload.url.value_counts()
# Out:
# http://upload.wikimedia.org/wikipedia/en/1/18/Monobook-bullet.png                                                                                           19
# http://upload.wikimedia.org/wikipedia/de/b/bc/Wiki.png                                                                                                       6
# http://upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/50px-Commons-logo.svg.png                                                               4
# http://upload.wikimedia.org/wikipedia/commons/5/5d/Checker-16x16.png                                                                                         4
# http://upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Emblem-important.svg/40px-Emblem-important.svg.png                                                  3
#                                                                                                                                                             ..
# http://upload.wikimedia.org/math/3/0/c/30c28f76ef7517dbd19df4d4c683dbe6.png                                                                                  1
# http://upload.wikimedia.org/wikipedia/commons/thumb/3/37/Warren_Christopher.jpg/75px-Warren_Christopher.jpg                                                  1
# http://upload.wikimedia.org/wikipedia/commons/thumb/d/d0/Creation_of_the_Sun_and_Moon_face_detail.jpg/200px-Creation_of_the_Sun_and_Moon_face_detail.jpg     1
# http://upload.wikimedia.org/wikipedia/commons/thumb/4/42/HNL_Wiki_Wiki_Bus.jpg/180px-HNL_Wiki_Wiki_Bus.jpg                                                   1
# http://upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Open_book_01.svg/30px-Open_book_01.svg.png                                                          1
# Name: url, Length: 447, dtype: int64

# %%
value = upload.pivot_table(columns=['url'], aggfunc='size')

# %%
print(value)
# Out:
# url
# http://upload.wikimedia.org/math/1/8/f/18f63800376271ee4b0efe1545744cd6.png    1
# http://upload.wikimedia.org/math/2/8/8/288da8cdc3c8f13bcc989c93fbf776bf.png    1
# http://upload.wikimedia.org/math/3/0/c/30c28f76ef7517dbd19df4d4c683dbe6.png    1
# http://upload.wikimedia.org/math/5/7/a/57a7da04466506abe49d195776112785.png    1
# http://upload.wikimedia.org/math/5/a/1/5a1414637812cb26ee3ddc194d2d6ad9.png    1
#                                                                               ..
# http://upload.wikimedia.org/wikipedia/nl/b/bc/Wiki.png                         1
# http://upload.wikimedia.org/wikipedia/nl/d/d1/Mensenmaatschappij.png           1
# http://upload.wikimedia.org/wikipedia/pl/b/bc/Wiki.png                         1
# http://upload.wikimedia.org/wikipedia/pt/b/bc/Wiki.png                         1
# http://upload.wikimedia.org/wikipedia/tr/b/bc/Wiki.png                         1
# Length: 447, dtype: int64

# %%
upload['count'] = upload.groupby(['url'])['url'].transform('count')
# Out:
# /tmp/ipykernel_173930/213673289.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upload['count'] = upload.groupby(['url'])['url'].transform('count')

# %%
upload.head()
# Out:
#    monotonic      timestamp  \
# 0  929840853  1190146243326
# 2  929840854  1190146243311
# 5  929840858  1190146243314
# 7  929840859  1190146243296
# 9  929840861  1190146243292
#
#                                                  url flag  count
# 0  http://upload.wikimedia.org/wikipedia/en/thumb...    -      1
# 2  http://upload.wikimedia.org/wikipedia/commons/...    -      1
# 5  http://upload.wikimedia.org/wikipedia/en/thumb...    -      4
# 7  http://upload.wikimedia.org/wikipedia/commons/...    -      1
# 9  http://upload.wikimedia.org/wikipedia/commons/...    -      1

# %%
upload.sort_values(by='count', ascending=False)
# Out:
#       monotonic      timestamp  \
# 475   929841329  1190146243449
# 696   929841551  1190146243544
# 1000  929841852  1190146243654
# 86    929840939  1190146243337
# 239   929841096    11901462434
# ...         ...            ...
# 393   929841246  1190146243427
# 391   929841244  1190146243456
# 388   929841241  1190146243428
# 387   929841239  1190146243451
# 1032  929841884  1190146243652
#
#                                                     url flag  count
# 475   http://upload.wikimedia.org/wikipedia/en/1/18/...    -     19
# 696   http://upload.wikimedia.org/wikipedia/en/1/18/...    -     19
# 1000  http://upload.wikimedia.org/wikipedia/en/1/18/...    -     19
# 86    http://upload.wikimedia.org/wikipedia/en/1/18/...    -     19
# 239   http://upload.wikimedia.org/wikipedia/en/1/18/...    -     19
# ...                                                 ...  ...    ...
# 393   http://upload.wikimedia.org/wikipedia/en/thumb...    -      1
# 391   http://upload.wikimedia.org/wikipedia/commons/...    -      1
# 388   http://upload.wikimedia.org/wikipedia/commons/...    -      1
# 387   http://upload.wikimedia.org/wikipedia/commons/...    -      1
# 1032  http://upload.wikimedia.org/wikipedia/commons/...    -      1
#
# [516 rows x 5 columns]

# %%
upload['timestamp'] = pd.to_datetime(upload['timestamp'], unit='ms')
# Out:
# /tmp/ipykernel_173930/909786650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upload['timestamp'] = pd.to_datetime(upload['timestamp'], unit='ms')

# %%
upload.head()
# Out:
#    monotonic               timestamp  \
# 0  929840853 2007-09-18 20:10:43.326
# 2  929840854 2007-09-18 20:10:43.311
# 5  929840858 2007-09-18 20:10:43.314
# 7  929840859 2007-09-18 20:10:43.296
# 9  929840861 2007-09-18 20:10:43.292
#
#                                                  url flag  count
# 0  http://upload.wikimedia.org/wikipedia/en/thumb...    -      1
# 2  http://upload.wikimedia.org/wikipedia/commons/...    -      1
# 5  http://upload.wikimedia.org/wikipedia/en/thumb...    -      4
# 7  http://upload.wikimedia.org/wikipedia/commons/...    -      1
# 9  http://upload.wikimedia.org/wikipedia/commons/...    -      1

# %%
upload.url.iloc[0]
# Out:
# 'http://upload.wikimedia.org/wikipedia/en/thumb/e/e4/James_Johnson.jpg/200px-James_Johnson.jpg'

# %%
upload.url.str.split('/', expand=True)
# Out:
#           0 1                      2          3        4      5  6   7  \
# 0     http:     upload.wikimedia.org  wikipedia       en  thumb  e  e4
# 2     http:     upload.wikimedia.org  wikipedia  commons  thumb  b  b9
# 5     http:     upload.wikimedia.org  wikipedia       en  thumb  4  4a
# 7     http:     upload.wikimedia.org  wikipedia  commons  thumb  9  9a
# 9     http:     upload.wikimedia.org  wikipedia  commons  thumb  6  6b
# ...     ... ..                   ...        ...      ...    ... ..  ..
# 1026  http:     upload.wikimedia.org  wikipedia       en  thumb  b  be
# 1028  http:     upload.wikimedia.org  wikipedia  commons  thumb  9  91
# 1029  http:     upload.wikimedia.org  wikipedia       en  thumb  6  6b
# 1030  http:     upload.wikimedia.org  wikipedia  commons  thumb  0  06
# 1032  http:     upload.wikimedia.org  wikipedia  commons  thumb  f  f3
#
#                                8                                 9
# 0              James_Johnson.jpg           200px-James_Johnson.jpg
# 2          Flag_of_Australia.svg    22px-Flag_of_Australia.svg.png
# 5               Commons-logo.svg         50px-Commons-logo.svg.png
# 7              Flag_of_Spain.svg        20px-Flag_of_Spain.svg.png
# 9      Cathedrale_d_angers_1.jpg   180px-Cathedrale_d_angers_1.jpg
# ...                          ...                               ...
# 1026     The_Blue_Lagoon_DVD.jpg     180px-The_Blue_Lagoon_DVD.jpg
# 1028        Wikiversity-logo.svg     35px-Wikiversity-logo.svg.png
# 1029  Hpheadquartersentrance.jpg  180px-Hpheadquartersentrance.jpg
# 1030           Estatuablanco.JPG           150px-Estatuablanco.JPG
# 1032            Open_book_01.svg         30px-Open_book_01.svg.png
#
# [516 rows x 10 columns]

# %%
wiki = df[df.url.str.contains('upload') == False]

# %%
wiki.head()
# Out:
#    monotonic      timestamp  \
# 1  929840856  1190146243321
# 3  929840855  1190146243301
# 4  929840857  1190146243303
# 6  929840860  1190146243325
# 8  929840862  1190146243297
#
#                                                  url flag
# 1         http://en.wikipedia.org/images/wiki-en.png    -
# 3  http://es.wikipedia.org/w/index.php?title=-&ac...    -
# 4  http://en.wikipedia.org/w/index.php?title=Medi...    -
# 6  http://en.wikipedia.org/skins-1.5/monobook/IE6...    -
# 8  http://pl.wikipedia.org/skins-1.5/common/image...    -

# %%
wiki.shape
# Out:
# (520, 4)

# %%
wiki.url.nunique()
# Out:
# 308

# %%
# wiki_value = wiki['url'].value_counts().reset_index(name='value').query('value > 1')

# %%
# wiki_value.head()

# %%
wiki.head()
# Out:
#    monotonic      timestamp  \
# 1  929840856  1190146243321
# 3  929840855  1190146243301
# 4  929840857  1190146243303
# 6  929840860  1190146243325
# 8  929840862  1190146243297
#
#                                                  url flag
# 1         http://en.wikipedia.org/images/wiki-en.png    -
# 3  http://es.wikipedia.org/w/index.php?title=-&ac...    -
# 4  http://en.wikipedia.org/w/index.php?title=Medi...    -
# 6  http://en.wikipedia.org/skins-1.5/monobook/IE6...    -
# 8  http://pl.wikipedia.org/skins-1.5/common/image...    -

# %%
wiki['count'] = wiki.groupby(['url'])['url'].transform('count')
# Out:
# /tmp/ipykernel_173930/922365937.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wiki['count'] = wiki.groupby(['url'])['url'].transform('count')

# %%
wiki.head()
# Out:
#    monotonic      timestamp  \
# 1  929840856  1190146243321
# 3  929840855  1190146243301
# 4  929840857  1190146243303
# 6  929840860  1190146243325
# 8  929840862  1190146243297
#
#                                                  url flag  count
# 1         http://en.wikipedia.org/images/wiki-en.png    -     10
# 3  http://es.wikipedia.org/w/index.php?title=-&ac...    -      3
# 4  http://en.wikipedia.org/w/index.php?title=Medi...    -     12
# 6  http://en.wikipedia.org/skins-1.5/monobook/IE6...    -      5
# 8  http://pl.wikipedia.org/skins-1.5/common/image...    -      1

# %%
wiki['url'].iloc[2]
# Out:
# 'http://en.wikipedia.org/w/index.php?title=MediaWiki:Monobook.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400'

# %%
wiki.sort_values(by=['count'], ascending=False)
# Out:
#      monotonic      timestamp  \
# 168  929841021  1190146243365
# 438  929841294  1190146243458
# 702  929841555  1190146243549
# 700  929841553  1190146243517
# 672  929841525  1190146243541
# ..         ...            ...
# 553  929841406  1190146243473
# 550  929841403  1190146243488
# 547  929841399  1190146243475
# 546  929841400  1190146243479
# 611  929841464  1190146243494
#
#                                                    url flag  count
# 168  http://en.wikipedia.org/w/index.php?title=Medi...    -     17
# 438  http://en.wikipedia.org/w/index.php?title=Medi...    -     17
# 702  http://en.wikipedia.org/w/index.php?title=Medi...    -     17
# 700  http://en.wikipedia.org/w/index.php?title=Medi...    -     17
# 672  http://en.wikipedia.org/w/index.php?title=Medi...    -     17
# ..                                                 ...  ...    ...
# 553  http://de.wikipedia.org/skins-1.5/monobook/ext...    -      1
# 550      http://en.wikipedia.org/wiki/Father_and_Scout    -      1
# 547                 http://en.wikipedia.org/wiki/Mahdi    -      1
# 546     http://de.wikipedia.org/wiki/Multiple_Sklerose    -      1
# 611  http://en.wikipedia.org/skins-1.5/common/ajax....    -      1
#
# [520 rows x 5 columns]

# %%
wiki['timestamp'] = pd.to_datetime(wiki['timestamp'], unit='ms')
# Out:
# /tmp/ipykernel_173930/2805859017.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wiki['timestamp'] = pd.to_datetime(wiki['timestamp'], unit='ms')

# %%
wiki.head(2)
# Out:
#    monotonic               timestamp  \
# 1  929840856 2007-09-18 20:10:43.321
# 3  929840855 2007-09-18 20:10:43.301
#
#                                                  url flag  count
# 1         http://en.wikipedia.org/images/wiki-en.png    -     10
# 3  http://es.wikipedia.org/w/index.php?title=-&ac...    -      3

# %%
wiki.url.unique()
# Out:
# array(['http://en.wikipedia.org/images/wiki-en.png',
#        'http://es.wikipedia.org/w/index.php?title=-&action=raw&gen=js&useskin=monobook',
#        'http://en.wikipedia.org/w/index.php?title=MediaWiki:Monobook.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400',
#        'http://en.wikipedia.org/skins-1.5/monobook/IE60Fixes.css?99',
#        'http://pl.wikipedia.org/skins-1.5/common/images/poweredby_mediawiki_88x31.png',
#        'http://pl.wikipedia.org/skins-1.5/common/commonPrint.css?99',
#        'http://de.wikipedia.org/skins-1.5/monobook/main.css?90',
#        'http://en.wikipedia.org/skins-1.5/common/images/magnify-clip.png',
#        'http://en.wikipedia.org/skins-1.5/monobook/headbg.jpg',
#        'http://en.wiktionary.org/wiki/revealed',
#        'http://en.wikipedia.org/wiki/Beowulf_%282007_film%29',
#        'http://pt.wikipedia.org/skins-1.5/common/images/button_sig.png',
#        'http://es.wikipedia.org/wiki/Cha%C3%AFm_Perelman',
#        'http://de.wikipedia.org/skins-1.5/monobook/main.css?99',
#        'http://hu.wikipedia.org/skins-1.5/monobook/headbg.jpg',
#        'http://de.wikipedia.org/wiki/Spezial:Search?search=steuerfreibetrag&go=Artikel&sourceid=mozilla-20',
#        'http://es.wikipedia.org/favicon.ico',
#        'http://de.wikipedia.org/skins-1.5/common/ajax.js?99',
#        'http://ca.wikipedia.org/w/index.php?title=-&action=raw&gen=css&maxage=2678400',
#        'http://en.wikipedia.org/skins-1.5/common/shared.css?99',
#        'http://es.wikipedia.org/w/index.php?title=MediaWiki:Common.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400',
#        'http://en.wikipedia.org/skins-1.5/common/ajax.js?99',
#        'http://fr.wikipedia.org/skins-1.5/common/images/magnify-clip.png',
#        'http://en.wikipedia.org/w/opensearch_desc.php',
#        'http://en.wikipedia.org/wiki/Special:Random',
#        'http://en.wikipedia.org/w/index.php?title=MediaWiki:Common.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400',
#        'http://sv.wikipedia.org/skins-1.5/monobook/headbg.jpg',
#        'http://fi.wikipedia.org/skins-1.5/monobook/external.png',
#        'http://fr.wikipedia.org/skins-1.5/monobook/headbg.jpg',
#        'http://es.wikipedia.org/wiki/Rochester_(Minnesota)',
#        'http://fi.wikipedia.org/skins-1.5/monobook/user.gif',
#        'http://fr.wikipedia.org/w/index.php?title=-&action=raw&gen=js&useskin=monobook',
#        'http://en.wikipedia.org/skins-1.5/monobook/main.css?99',
#        'http://en.wikipedia.org/wiki/hoss_%28professional_wrestling%29',
#        'http://fr.wikipedia.org/skins-1.5/common/ajax.js?99',
#        'http://it.wikipedia.org/w/index.php?title=MediaWiki:Monobook.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400',
#        'http://es.wikipedia.org/wiki/Fecundidad',
#        'http://sv.wikipedia.org/w/opensearch_desc.php',
#        'http://de.wikipedia.org/skins-1.5/common/images/button_sig.png',
#        'http://de.wikipedia.org/w/extensions/wikihiero/img/hiero_V31.png',
#        'http://de.wikipedia.org/skins-1.5/monobook/headbg.jpg',
#        'http://meta.wikimedia.org/w/index.php?title=MediaWiki:Wikiminiatlas.js&action=raw&ctype=text/javascript&smaxage=21600&maxage=86400',
#        'http://pt.wikipedia.org/wiki/Especial:Search?search=amianto',
#        'http://de.wikipedia.org/skins-1.5/common/images/magnify-clip.png',
#        'http://de.wikipedia.org/skins-1.5/common/shared.css?99',
#        'http://en.wikipedia.org/w/index.php?title=Special:Upload&uselang=fromowner',
#        'http://en.wikipedia.org/skins-1.5/common/images/poweredby_mediawiki_88x31.png',
#        'http://en.wikipedia.org/skins-1.5/monobook/user.gif',
#        'http://fr.wikipedia.org/skins-1.5/common/shared.css?99',
#        'http://de.wikipedia.org/w/index.php?title=-&action=raw&gen=css&maxage=2678400',
#        'http://www.wikipedia.com/',
#        'http://en.wikipedia.org/wiki/Uncle_Tupelo',
#        'http://pt.wikipedia.org/skins-1.5/common/ajax.js?99',
#        'http://en.wikipedia.org/skins-1.5/monobook/bullet.gif',
#        'http://en.wikipedia.org/w/index.php?title=-&action=raw&gen=css&maxage=2678400',
#        'http://hi.wikipedia.org/wiki/',
#        'http://pl.wikipedia.org/w/index.php?title=-&action=raw&gen=css&maxage=2678400',
#        'http://de.wikipedia.org/wiki/Tuberkulose',
#        'http://ja.wikipedia.org/skins-1.5/common/wikibits.js?99',
#        'http://en.wiktionary.org/wiki/Wiktionary:Main_Page',
#        'http://en.wikipedia.org/wiki/Special:Search?search=Family+Guy&go=Go',
#        'http://en.wikipedia.org/w/index.php?title=-&action=raw&gen=js&useskin=monobook',
#        'http://en.wikipedia.org/wiki/Germany',
#        'http://en.wikipedia.org/skins-1.5/common/metadata.js?99',
#        'http://en.wikipedia.org/skins-1.5/common/wikibits.js?99',
#        'http://en.wikipedia.org/wiki/Miles_%22Tails%22_Prower',
#        'http://en.wikipedia.org/wiki/Spirulina_(dietary_supplement)',
#        'http://fr.wikipedia.org/skins-1.5/monobook/IE70Fixes.css?99',
#        'http://es.wikipedia.org/skins-1.5/common/images/button_bold.png',
#        'http://pl.wikipedia.org/wiki/Pieni%C4%85dze_brytyjskie',
#        'http://fr.wikipedia.org/wiki/Jon_Voight',
#        'http://es.wikipedia.org/wiki/Wolfgang_Amadeus_Mozart',
#        'http://en.wikipedia.org/skins-1.5/common/commonPrint.css?99',
#        'http://pt.wikipedia.org/skins-1.5/common/IEFixes.js?99',
#        'http://en.wikibooks.org/images/wikimedia-button.png',
#        'http://es.wikipedia.org/skins-1.5/monobook/bullet.gif',
#        'http://it.wikipedia.org/skins-1.5/common/IEFixes.js?99',
#        'http://en.wikipedia.org/wiki/Inktomi',
#        'http://de.wikipedia.org/skins-1.5/common/images/button_italic.png',
#        'http://en.wikipedia.org/wiki/Bratz',
#        'http://en.wikipedia.org/skins-1.5/monobook/external.png',
#        'http://es.wikipedia.org/wiki/Imagen:Series_of_an_ejaculating_penis.JPG',
#        'http://pl.wikipedia.org/skins-1.5/monobook/headbg.jpg',
#        'http://es.wikipedia.org/images/wikimedia-button.png',
#        'http://www.wikipedia.org/',
#        'http://en.wikipedia.org/skins-1.5/common/IEFixes.js?99',
#        'http://en.wikipedia.org/images/wikimedia-button.png',
#        'http://es.wikipedia.org/skins-1.5/common/commonPrint.css?99',
#        'http://es.wikipedia.org/skins-1.5/monobook/IE60Fixes.css?99',
#        'http://pl.wikipedia.org/w/index.php?title=MediaWiki:Common.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400',
#        'http://pl.wikipedia.org/skins-1.5/monobook/user.gif',
#        'http://en.wikipedia.org/wiki/Jewish_holiday',
#        'http://es.wikipedia.org/skins-1.5/monobook/user.gif',
#        'http://pt.wikipedia.org/skins-1.5/monobook/main.css?99',
#        'http://en.wikipedia.org/skins-1.5/common/commonPrint.css?97',
#        'http://en.wikipedia.org/wiki/The_Pianist_(2002_film)',
#        'http://de.wikipedia.org/w/index.php?title=MediaWiki:SpezialSuche.js&action=raw&ctype=text/javascript&dontcountme=s&smaxage=3600',
#        'http://meta.wikimedia.org/w/index.php?title=MediaWiki:Wikiminiatlas.js&action=raw&ctype=text/javascript&dontcountme=s',
#        'http://meta.wikimedia.org/style/monobook/main.css',
#        'http://pl.wikipedia.org/wiki/PZL_W-3_Sok%C3%B3%C5%82',
#        'http://es.wikipedia.org/skins-1.5/monobook/headbg.jpg',
#        'http://de.wikipedia.org/wiki/Spezial:Suche?search=vom+guten+menschen',
#        'http://pl.wikipedia.org/w/index.php?title=MediaWiki:Youvegotmail.js&action=raw&ctype=text/javascript&dontcountme=s',
#        'http://en.wikipedia.org/style/IEFixes.js',
#        'http://en.wikipedia.org/w/extensions/LuceneSearch/lucenesearch.css',
#        'http://es.wikipedia.org/w/index.php?title=MediaWiki:Monobook.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400',
#        'http://pl.wikipedia.org/skins-1.5/monobook/main.css?97',
#        'http://de.wikipedia.org/wiki/FIPS_%28Partitionierungssoftware%29',
#        'http://en.wikipedia.org/wiki/Hugh_O%27Donnell%2C_2nd_Earl_of_Tyrconnell',
#        'http://pl.wikipedia.org/wiki/Ben_Kowalewicz',
#        'http://en.wikipedia.org/wiki/Spotting_%28weight_training%29',
#        'http://es.wikipedia.org/w/index.php?title=MediaWiki:Edittools.js&action=raw&smaxage=3600&ctype=text/javascript&dontcountme=s',
#        'http://fr.wikipedia.org/w/index.php?title=MediaWiki:Monobook.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400',
#        'http://en.wikipedia.org/w/index.php?title=Culture_of_ancient_Rome&action=edit&section=2',
#        'http://fr.wikipedia.org/skins-1.5/monobook/bullet.gif',
#        'http://es.wikipedia.org/wiki/Talud-tablero',
#        'http://en.wikipedia.org/wiki/Charles_Darwin',
#        'http://fr.wikipedia.org/w/index.php?title=MediaWiki:Common.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400',
#        'http://en.wikipedia.org/style/monobook/null?',
#        'http://es.wikipedia.org/wiki/Nivel_de_red',
#        'http://war.wikipedia.org/skins-1.5/monobook/bullet.gif',
#        'http://de.wikipedia.org/w/index.php?title=Steve_Fossett&diff=prev&oldid=36847673',
#        'http://es.wikipedia.org/wiki/Ion',
#        'http://fr.wiktionary.org/skins-1.5/monobook/bullet.gif',
#        'http://es.wikipedia.org/w/extensions/LuceneSearch/lucenesearch.css',
#        'http://ja.wikipedia.org/skins-1.5/common/shared.css?99',
#        'http://en.wikipedia.org/wiki/Image:Black_Box_-_Ride_On_Time_excerpt.ogg',
#        'http://it.wikipedia.org/skins-1.5/monobook/headbg.jpg',
#        'http://en.wikipedia.org/wiki/Gwen',
#        'http://de.wikipedia.org/wiki/Bild:Bev%C3%B6lkerungsdichte_Japans.png',
#        'http://en.wikipedia.org/wiki/Monadnock',
#        'http://en.wikipedia.org/wiki/Sora_%28.hack%29',
#        'http://sk.wikipedia.org/skins-1.5/common/shared.css?99',
#        'http://no.wikipedia.org/skins-1.5/common/wikibits.js?99',
#        'http://it.wikiquote.org/skins-1.5/common/images/button_image.png',
#        'http://de.wikipedia.org/skins-1.5/monobook/user.gif',
#        'http://bn.wikipedia.org/skins-1.5/common/images/magnify-clip.png',
#        'http://et.wikipedia.org/wiki/K%C3%A4rbes',
#        'http://he.wikipedia.org/skins-1.5/common/shared.css?97',
#        'http://en.wikipedia.org/wiki/Rose_Is_Rose',
#        'http://en.wikipedia.org/skins-1.5/common/shared.css?97',
#        'http://es.wikipedia.org/skins-1.5/common/shared.css?99',
#        'http://de.wikipedia.org/wiki/Bild:1000DM-Vorderseite.jpg',
#        'http://de.wikipedia.org/wiki/Spitz_%28Hunderasse%29',
#        'http://en.wikipedia.org/wiki/List_of_Good_Eats_episodes',
#        'http://es.wikipedia.org/skins-1.5/common/images/poweredby_mediawiki_88x31.png',
#        'http://en.wikipedia.org/wiki/Judgment_at_Nuremberg',
#        'http://en.wikipedia.org/wiki/Public_relations',
#        'http://de.wikipedia.org/wiki/Spezial:Search/Valmy',
#        'http://en.wikipedia.org/w/index.php?title=-&action=raw&smaxage=0&gen=js&useskin=monobook',
#        'http://en.wikipedia.org/wiki/Cryptid',
#        'http://es.wikipedia.org/skins-1.5/monobook/main.css?99',
#        'http://es.wikipedia.org/skins-1.5/common/images/button_extlink.png',
#        'http://en.wikipedia.org/wiki/Mustrum_Ridcully',
#        'http://en.wikipedia.org/wiki/Special:Search?search=Tourgasm',
#        'http://en.wikipedia.org/skins-1.5/common/wikibits.js?97',
#        'http://en.wikipedia.org/wiki/Eliza_Manningham-Buller',
#        'http://en.wikipedia.org/wiki/Main_Page',
#        'http://pl.wikipedia.org/images/wikimedia-button.png',
#        'http://commons.wikimedia.org/w/index.php?title=MediaWiki:Quick-delete.js&action=raw&ctype=text/javascript',
#        'http://ar.wikipedia.org/w/index.php?title=%D9%85%D9%8A%D8%AF%D9%8A%D8%A7%D9%88%D9%8A%D9%83%D9%8A:Monobook.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400',
#        'http://es.wikipedia.org/skins-1.5/common/IEFixes.js?99',
#        'http://nl.wikipedia.org/skins-1.5/monobook/main.css?99',
#        'http://de.wikipedia.org/w/extensions/wikihiero/img/hiero_D21.png',
#        'http://es.wikipedia.org/skins-1.5/common/images/button_headline.png',
#        'http://pt.wikipedia.org/wiki/Caroteno',
#        'http://en.wikipedia.org/wiki/Revivalism',
#        'http://es.wikipedia.org/wiki/Aleister_Crowley',
#        'http://en.wikipedia.org/style/monobook/IE60Fixes.css',
#        'http://en.wikipedia.org/skins-1.5/monobook/main.css?97',
#        'http://it.wikipedia.org/skins-1.5/monobook/external.png',
#        'http://pt.wikipedia.org/w/index.php?title=MediaWiki:Common.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400',
#        'http://ar.wikipedia.org/skins-1.5/common/commonPrint.css?97',
#        'http://it.wikipedia.org/skins-1.5/monobook/user.gif',
#        'http://ja.wikipedia.org/skins-1.5/common/images/poweredby_mediawiki_88x31.png',
#        'http://sv.wikipedia.org/skins-1.5/common/ajax.js?99',
#        'http://he.wikipedia.org/skins-1.5/monobook/main.css?99',
#        'http://en.wikipedia.org/wiki/Special:Search?search=karam+apna+apna',
#        'http://en.wikipedia.org/wiki/Sheave_(mechanical)',
#        'http://es.wikipedia.org/skins-1.5/common/wikibits.js?99',
#        'http://de.wikipedia.org/w/extensions/LuceneSearch/lucenesearch.css',
#        'http://he.wikipedia.org/skins-1.5/common/shared.css?99',
#        'http://de.wikipedia.org/skins-1.5/common/wikibits.js?99',
#        'http://fr.wikipedia.org/skins-1.5/common/images/button_math.png',
#        'http://de.wikipedia.org/wiki/Multiple_Sklerose',
#        'http://en.wikipedia.org/wiki/Mahdi',
#        'http://en.wikipedia.org/wiki/Father_and_Scout',
#        'http://de.wikipedia.org/skins-1.5/monobook/external.png',
#        'http://en.wikipedia.org/wiki/Conquistador',
#        'http://en.wikipedia.org/wiki/Special:Search?search=graviton&go=Go',
#        'http://en.wikipedia.org/wiki/Characters_in_Tsukihime',
#        'http://en.wikipedia.org/wiki/Force_%28Star_Wars%29',
#        'http://en.wikipedia.org/wiki/Death_In_June',
#        'http://en.wikipedia.org/favicon.ico',
#        'http://en.wikipedia.org/wiki/Dayton',
#        'http://en.wikipedia.org/wiki/Duality_%28song%29',
#        'http://pt.wikipedia.org/skins-1.5/monobook/headbg.jpg',
#        'http://en.wikipedia.org/wiki/Wanderlei_Silva',
#        'http://en.wikipedia.org/wiki/Ancient_Greece',
#        'http://de.wiktionary.org/skins-1.5/monobook/bullet.gif',
#        'http://en.wikipedia.org/wiki/Theremin',
#        'http://nl.wikipedia.org/skins-1.5/monobook/main.css?90',
#        'http://es.wikipedia.org/skins-1.5/common/ajax.js?99',
#        'http://fr.wikipedia.org/wiki/Zona',
#        'http://wikimediafoundation.org/w/index.php?title=MediaWiki:Common.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400',
#        'http://en.wikibooks.org/skins-1.5/monobook/headbg.jpg',
#        'http://en.wikipedia.org/skins-1.5/common/ajax.js?97',
#        'http://www.wikipedia.org/search-redirect.php?search=vaclav+havel&language=en&go=++%3E++&go=Go',
#        'http://ja.wikipedia.org/w/index.php?title=%E5%8F%97%E4%BF%A1%E6%84%9F%E5%BA%A6&redirect=no',
#        'http://de.wikipedia.org/skins-1.5/monobook/IE60Fixes.css?99',
#        'http://en.wikipedia.org/wiki/Salvador_Dal%C3%AD',
#        'http://en.wikipedia.org/wiki/Yorkshire_Terrier',
#        'http://es.wikipedia.org/skins-1.5/monobook/IE70Fixes.css?99',
#        'http://tr.wikipedia.org/skins-1.5/monobook/video.png',
#        'http://commons.wikimedia.org/skins-1.5/monobook/user.gif',
#        'http://en.wikipedia.org/wiki/Image:Chatterton.jpg',
#        'http://commons.wikimedia.org/skins-1.5/common/commonPrint.css?99',
#        'http://es.wikipedia.org/w/index.php?title=MediaWiki:Wikimediaplayer.js&action=raw&ctype=text/javascript&dontcountme=s&smaxage=3600',
#        'http://it.wikipedia.org/wiki/Jean-%C3%89tienne_Liotard',
#        'http://en.wikipedia.org/wiki/Mean_Girls',
#        'http://es.wikipedia.org/wiki/Imagen:Illu_epithelium.jpg',
#        'http://en.wikipedia.org/wiki/Virginie_Ledoyen',
#        'http://es.wikipedia.org/w/index.php?title=-&action=raw&gen=css&maxage=2678400',
#        'http://pl.wikipedia.org/skins-1.5/monobook/document.png',
#        'http://de.wiktionary.org/skins-1.5/common/wikibits.js?99',
#        'http://de.wikipedia.org/w/index.php?title=MediaWiki:Monobook.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400',
#        'http://www.wikipedia.org/search-redirect.php?search=rick+astley&language=en&go=Go',
#        'http://pt.wikipedia.org/skins-1.5/common/images/magnify-clip.png',
#        'http://en.wikinews.org/w/wiki.phtml?title=Special:Recentchanges&feed=rss',
#        'http://fr.wiktionary.org/skins-1.5/common/IEFixes.js?99',
#        'http://pl.wikipedia.org/wiki/Geografia%20Irlandii%20-%20Wikipedia',
#        'http://de.wikipedia.org/wiki/Bill_Cosby',
#        'http://nl.wikipedia.org/skins-1.5/monobook/IE70Fixes.css?90',
#        'http://en.wikipedia.org/wiki/',
#        'http://de.wikipedia.org/w/index.php?title=MediaWiki:Pagecounter.js&action=raw&ctype=text/javascript&dontcountme=s&smaxage=3600',
#        'http://es.wikipedia.org/w/index.php?title=MediaWiki:NavigationBar.js&action=raw&smaxage=3600&ctype=text/javascript&dontcountme=s',
#        'http://es.wikipedia.org/skins-1.5/monobook/Opera7Fixes.css',
#        'http://en.wikipedia.org/wiki/Newark_Liberty_International_Airport',
#        'http://commons.wikimedia.org/w/index.php?title=MediaWiki:ResizeGalleries.js&action=raw&ctype=text/javascript',
#        'http://de.wikipedia.org/w/index.php?title=-&action=raw&gen=js&useskin=monobook',
#        'http://csb.wikipedia.org/skins-1.5/common/shared.css?99',
#        'http://fi.wikipedia.org/w/index.php?title=-&action=raw&smaxage=0&gen=js&useskin=monobook',
#        'http://de.wikipedia.org/wiki/Klaus_Wabra',
#        'http://de.wikipedia.org/w/index.php?title=MediaWiki:Common.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400',
#        'http://en.wikipedia.org/wiki/Special:Search?search=&go=Go',
#        'http://de.wikipedia.org/wiki/Spezial:Suche?search=%C3%BCbergesetzlicher+Notstand&go=Artikel',
#        'http://en.wikipedia.org/w/index.php?title=Portal:Current_events/2007_January_7&action=history&feed=atom',
#        'http://commons.wikimedia.org/w/index.php?title=-&action=raw&gen=css&maxage=2678400',
#        'http://www.wikimedia.org/favicon.ico',
#        'http://de.wikipedia.org/wiki/Schnurrbart',
#        'http://www.wikipedia.org/search-redirect.php?search=Second+Sight&language=en&go=++%3E++&go=Go',
#        'http://pt.wikipedia.org/skins-1.5/common/shared.css?99',
#        'http://pl.wikipedia.org/wiki/W%C5%82adca_much',
#        'http://fr.wikipedia.org/skins-1.5/monobook/main.css?99',
#        'http://fr.wikipedia.org/skins-1.5/monobook/main.css?97',
#        'http://en.wikipedia.org/wiki/Black_Velvet_(beer_cocktail)',
#        'http://en.wikipedia.org/wiki/Joan_Crawford',
#        'http://es.wikipedia.org/skins-1.5/monobook/main.css?90',
#        'http://ja.wikipedia.org/w/index.php?title=MediaWiki:Monobook.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400',
#        'http://es.wikipedia.org/wiki/Poker',
#        'http://fr.wikipedia.org/w/index.php?title=-&action=raw&gen=css&maxage=2678400',
#        'http://ja.wikipedia.org/wiki/%E5%B8%82%E4%BA%95%E7%B4%97%E8%80%B6%E9%A6%99',
#        'http://en.wikipedia.org/wiki/1918',
#        'http://he.wikipedia.org/skins-1.5/common/images/poweredby_mediawiki_88x31.png',
#        'http://fr.wikipedia.org/skins-1.5/monobook/external.png',
#        'http://de.wikipedia.org/favicon.ico',
#        'http://pt.wikipedia.org/w/index.php?title=-&action=raw&gen=css&maxage=2678400',
#        'http://nl.wikipedia.org/skins-1.5/monobook/headbg.jpg',
#        'http://en.wikipedia.org/wiki/Image:Arodpractice.JPG',
#        'http://lt.wikipedia.org/wiki/Macropoly',
#        'http://en.wikipedia.org/wiki/Land_of_Sound',
#        'http://en.wikipedia.org/wiki/Valley_of_the_Damned_-_Remixed_%26_Remastered',
#        'http://en.wikipedia.org/style/commonPrint.css',
#        'http://sv.wikipedia.org/w/index.php?title=MediaWiki:Common.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400',
#        'http://en.wikipedia.org/wiki/New_York_Yankees',
#        'http://de.wikipedia.org/w/opensearch_desc.php',
#        'http://en.wikipedia.org/wiki/List_of_Latin_abbreviations',
#        'http://tr.wikipedia.org/skins-1.5/monobook/external.png',
#        'http://pl.wikipedia.org/wiki/Specjalna:Contributions/83.6.22.78?namespace=0&limit=60',
#        'http://nl.wikipedia.org/skins-1.5/common/shared.css?99',
#        'http://en.wikipedia.org/wiki/Special:Search/brandi%20carlile',
#        'http://en.wikipedia.org/wiki/Calcium',
#        'http://it.wikipedia.org/skins-1.5/common/commonPrint.css?99',
#        'http://en.wikipedia.org/wiki/Eric_Pohlmann',
#        'http://pl.wikipedia.org/skins-1.5/common/wikibits.js?99',
#        'http://pl.wikipedia.org/wiki/Analiza_SWOT',
#        'http://pt.wikipedia.org/wiki/Esquim%C3%B3',
#        'http://pt.wikipedia.org/skins-1.5/monobook/IE60Fixes.css?99',
#        'http://fr.wikipedia.org/wiki/Entreprise',
#        'http://it.wikipedia.org/skins-1.5/common/images/magnify-clip.png',
#        'http://en.wikipedia.org/w/extensions/OggHandler/play.png',
#        'http://en.wikipedia.org/wiki/On_Your_Feet_Or_On_Your_Knees',
#        'http://en.wikipedia.org/skins-1.5/common/images/button_extlink.png',
#        'http://en.wikipedia.org/wiki/Archipelago',
#        'http://de.wikipedia.org/wiki/Fungizid',
#        'http://en.wikipedia.org/wiki/Nate_Kaeding',
#        'http://tr.wikipedia.org/skins-1.5/common/images/button_sig.png',
#        'http://de.wikipedia.org/wiki/Spezial:Suche?search=Syntax&go=Artikel',
#        'http://en.wikipedia.org/w/extensions/CategoryTree/CategoryTree.css?1',
#        'http://commons.wikimedia.org/w/index.php?title=MediaWiki:Edittools.js&action=raw&ctype=text/javascript',
#        'http://en.wikipedia.org/wiki/Infiniti_QX56',
#        'http://en.wikipedia.org/skins-1.5/monobook/IE60Fixes.css?97',
#        'http://it.wikipedia.org/skins-1.5/monobook/main.css?99',
#        'http://en.wikipedia.org/wiki/Microsoft_Visual_Studio',
#        'http://en.wikipedia.org/wiki/Special:Search?search=US+VP',
#        'http://en.wikipedia.org/wiki/Florence_Nightingale',
#        'http://commons.wikimedia.org/w/index.php?title=Mediawiki:Wikimediaplayer.js&action=raw&ctype=text/javascript&dontcountme=s',
#        'http://en.wikipedia.org/wiki/List_of_The_4400_episodes'],
#       dtype=object)

# %%
wiki.url.str[7:9].value_counts()
# Out:
# en    268
# es     60
# de     49
# pl     24
# fr     22
# me     18
# pt     13
# it     10
# ww      9
# co      7
# ja      6
# nl      5
# sv      5
# he      4
# fi      3
# tr      3
# no      2
# ar      2
# hu      1
# cs      1
# wi      1
# et      1
# bn      1
# sk      1
# wa      1
# ca      1
# hi      1
# lt      1
# Name: url, dtype: int64

# %%
wiki[wiki.url.str.contains('.jpg')]
# Out:
#      monotonic               timestamp  \
# 16   929840869 2007-09-18 20:10:43.322
# 22   929840876 2007-09-18 20:10:43.319
# 48   929840904 1973-10-09 11:37:04.331
# 50   929840902 2007-09-18 20:10:43.308
# 75   929840929 2007-09-18 20:10:43.325
# 180  929841037 2007-09-18 20:10:43.354
# 252  929841106 2007-09-18 20:10:43.395
# 331  929841185 2007-09-18 20:10:43.407
# 355  929841209 2007-09-18 20:10:43.419
# 395  929841248 2007-09-18 20:10:43.431
# 454  929841306 2007-09-18 20:10:43.464
# 469  929841322 2007-09-18 20:10:43.465
# 583  929841437 2007-09-18 20:10:43.512
# 608  929841462 2007-09-18 20:10:43.494
# 638  929841491 2007-09-18 20:10:43.526
# 650  929841503 2007-09-18 20:10:43.538
# 686  929841539 2007-09-18 20:10:43.545
# 715  929841569 2007-09-18 20:10:43.553
# 820  929841669 2007-09-18 20:10:43.561
# 841  929841694 2007-09-18 20:10:43.577
# 871  929841724 1973-10-09 11:37:04.361
# 937  929841790 2007-09-18 20:10:43.625
# 956  929841810 2007-09-18 20:10:43.604
#
#                                                    url flag  count
# 16   http://en.wikipedia.org/skins-1.5/monobook/hea...    -      6
# 22   http://hu.wikipedia.org/skins-1.5/monobook/hea...    -      1
# 48   http://sv.wikipedia.org/skins-1.5/monobook/hea...    -      1
# 50   http://fr.wikipedia.org/skins-1.5/monobook/hea...    -      1
# 75   http://de.wikipedia.org/skins-1.5/monobook/hea...    -      2
# 180  http://pl.wikipedia.org/skins-1.5/monobook/hea...    -      2
# 252  http://es.wikipedia.org/skins-1.5/monobook/hea...    -      3
# 331  http://it.wikipedia.org/skins-1.5/monobook/hea...    -      1
# 355  http://pl.wikipedia.org/skins-1.5/monobook/hea...    -      2
# 395  http://de.wikipedia.org/wiki/Bild:1000DM-Vorde...    -      1
# 454  http://es.wikipedia.org/skins-1.5/monobook/hea...    -      3
# 469  http://en.wikipedia.org/skins-1.5/monobook/hea...    -      6
# 583  http://pt.wikipedia.org/skins-1.5/monobook/hea...    -      1
# 608  http://en.wikibooks.org/skins-1.5/monobook/hea...    -      1
# 638  http://en.wikipedia.org/wiki/Image:Chatterton.jpg    -      1
# 650  http://es.wikipedia.org/wiki/Imagen:Illu_epith...    -      1
# 686  http://en.wikipedia.org/skins-1.5/monobook/hea...    -      6
# 715  http://en.wikipedia.org/skins-1.5/monobook/hea...    -      6
# 820  http://nl.wikipedia.org/skins-1.5/monobook/hea...    -      1
# 841  http://en.wikipedia.org/skins-1.5/monobook/hea...    -      6
# 871  http://en.wikipedia.org/skins-1.5/monobook/hea...    -      6
# 937  http://es.wikipedia.org/skins-1.5/monobook/hea...    -      3
# 956  http://de.wikipedia.org/skins-1.5/monobook/hea...    -      2

# %%
wiki[wiki.url.str.contains('/wiki/')]
# Out:
#       monotonic               timestamp  \
# 17    929840870 2007-09-18 20:10:43.327
# 18    929840871 2007-09-18 20:10:43.326
# 20    929840873 2007-09-18 20:10:43.322
# 24    929840877 2007-09-18 20:10:43.309
# 45    929840896 2007-09-18 20:10:43.322
# ...         ...                     ...
# 1001  929841858 2007-09-18 20:10:43.625
# 1019  929841873 1973-10-09 11:37:04.365
# 1022  929841875 1973-10-09 11:37:04.364
# 1031  929841885 1973-10-09 11:37:04.366
# 1034  929841890 2007-09-18 20:10:43.655
#
#                                                     url flag  count
# 17               http://en.wiktionary.org/wiki/revealed    -      1
# 18    http://en.wikipedia.org/wiki/Beowulf_%282007_f...    -      1
# 20     http://es.wikipedia.org/wiki/Cha%C3%AFm_Perelman    -      1
# 24    http://de.wikipedia.org/wiki/Spezial:Search?se...    -      1
# 45          http://en.wikipedia.org/wiki/Special:Random    -      3
# ...                                                 ...  ...    ...
# 1001         http://en.wikipedia.org/wiki/Infiniti_QX56    -      1
# 1019  http://en.wikipedia.org/wiki/Microsoft_Visual_...    -      1
# 1022  http://en.wikipedia.org/wiki/Special:Search?se...    -      1
# 1031  http://en.wikipedia.org/wiki/Florence_Nightingale    -      1
# 1034  http://en.wikipedia.org/wiki/List_of_The_4400_...    -      1
#
# [119 rows x 5 columns]

# %%
wiki.url.str.split('/', expand=True)
# Out:
#           0 1                       2          3  \
# 1     http:          en.wikipedia.org     images
# 3     http:          es.wikipedia.org          w
# 4     http:          en.wikipedia.org          w
# 6     http:          en.wikipedia.org  skins-1.5
# 8     http:          pl.wikipedia.org  skins-1.5
# ...     ... ..                    ...        ...
# 1027  http:          en.wikipedia.org          w
# 1031  http:          en.wikipedia.org       wiki
# 1033  http:     commons.wikimedia.org          w
# 1034  http:          en.wikipedia.org       wiki
# 1035  http:        meta.wikimedia.org          w
#
#                                                       4  \
# 1                                           wiki-en.png
# 3     index.php?title=-&action=raw&gen=js&useskin=mo...
# 4     index.php?title=MediaWiki:Monobook.css&usemsgc...
# 6                                              monobook
# 8                                                common
# ...                                                 ...
# 1027  index.php?title=-&action=raw&gen=js&useskin=mo...
# 1031                               Florence_Nightingale
# 1033  index.php?title=Mediawiki:Wikimediaplayer.js&a...
# 1034                          List_of_The_4400_episodes
# 1035  index.php?title=MediaWiki:Wikiminiatlas.js&act...
#
#                                           5                              6  \
# 1                                      None                           None
# 3                                      None                           None
# 4                       css&smaxage=2678400                           None
# 6                          IE60Fixes.css?99                           None
# 8                                    images  poweredby_mediawiki_88x31.png
# ...                                     ...                            ...
# 1027                                   None                           None
# 1031                                   None                           None
# 1033               javascript&dontcountme=s                           None
# 1034                                   None                           None
# 1035  javascript&smaxage=21600&maxage=86400                           None
#
#          7
# 1     None
# 3     None
# 4     None
# 6     None
# 8     None
# ...    ...
# 1027  None
# 1031  None
# 1033  None
# 1034  None
# 1035  None
#
# [520 rows x 8 columns]

# %%
wiki
# Out:
#       monotonic               timestamp  \
# 1     929840856 2007-09-18 20:10:43.321
# 3     929840855 2007-09-18 20:10:43.301
# 4     929840857 2007-09-18 20:10:43.303
# 6     929840860 2007-09-18 20:10:43.325
# 8     929840862 2007-09-18 20:10:43.297
# ...         ...                     ...
# 1027  929841880 2007-09-18 20:10:43.628
# 1031  929841885 1973-10-09 11:37:04.366
# 1033  929841887 2007-09-18 20:10:43.628
# 1034  929841890 2007-09-18 20:10:43.655
# 1035  929841892 2007-09-18 20:10:43.656
#
#                                                     url flag  count
# 1            http://en.wikipedia.org/images/wiki-en.png    -     10
# 3     http://es.wikipedia.org/w/index.php?title=-&ac...    -      3
# 4     http://en.wikipedia.org/w/index.php?title=Medi...    -     12
# 6     http://en.wikipedia.org/skins-1.5/monobook/IE6...    -      5
# 8     http://pl.wikipedia.org/skins-1.5/common/image...    -      1
# ...                                                 ...  ...    ...
# 1027  http://en.wikipedia.org/w/index.php?title=-&ac...    -     14
# 1031  http://en.wikipedia.org/wiki/Florence_Nightingale    -      1
# 1033  http://commons.wikimedia.org/w/index.php?title...    -      1
# 1034  http://en.wikipedia.org/wiki/List_of_The_4400_...    -      1
# 1035  http://meta.wikimedia.org/w/index.php?title=Me...    -     15
#
# [520 rows x 5 columns]

# %%
wiki.loc[4][2]
# Out:
# 'http://en.wikipedia.org/w/index.php?title=MediaWiki:Monobook.css&usemsgcache=yes&action=raw&ctype=text/css&smaxage=2678400'
